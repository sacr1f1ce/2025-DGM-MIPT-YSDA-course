# %% [markdown]
# <a href="https://colab.research.google.com/github/r-isachenko/2024-DGM-MIPT-YSDA-course/blob/main/seminars/seminar1/PixelCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.optim as optim
import torch.nn as nn
import torch.utils.data as Tdata
import torch.nn.functional as F
from tqdm.notebook import tqdm

if torch.cuda.is_available():
    DEVICE = 'cuda'
    # GPU_DEVICE = 2
    # torch.cuda.set_device(GPU_DEVICE)
else:
    DEVICE='cpu'

import warnings
warnings.filterwarnings('ignore')

# typing
from typing import List, Tuple

# %% [markdown]
# ## dgm_utils

# %% [markdown]
# 1. data
# 2. model
# 3. train
# 4. visualize

# %% [markdown]
# ## Problem setup

# %%
# colab dgm_utils install
COMMIT_HASH = "9c3ef18c821268297f31d45e36c3b0f2bb538a80"
# !if [ -d dgm_utils ]; then rm -Rf dgm_utils; fi
# !git clone https://github.com/r-isachenko/dgm_utils.git
# %cd dgm_utils
# !git checkout {COMMIT_HASH}
# !pip install ./
# %cd ./..
# !rm -Rf dgm_utils
# Out:
# Cloning into 'dgm_utils'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 134 (delta 83), reused 89 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 26.47 KiB | 2.94 MiB/s, done.
# Resolving deltas: 100% (83/83), done.
# /home/jovyan/morozov_ma/dgm/dgm_utils
# Processing /home/jovyan/morozov_ma/dgm/dgm_utils
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (2.2.2)
# Requirement already satisfied: matplotlib in /home/jovyan/.local/lib/python3.11/site-packages (from dgm_utils==0.1.1) (3.9.2)
# Requirement already satisfied: pillow in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (11.1.0)
# Requirement already satisfied: tqdm in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (4.67.1)
# Requirement already satisfied: torch in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (2.6.0)
# Requirement already satisfied: torchvision in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (0.21.0)
# Requirement already satisfied: torchaudio in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (2.6.0)
# Requirement already satisfied: gdown in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (5.2.0)
# Requirement already satisfied: scikit-learn in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from dgm_utils==0.1.1) (1.6.1)
# Requirement already satisfied: beautifulsoup4 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from gdown->dgm_utils==0.1.1) (4.13.3)
# Requirement already satisfied: filelock in /home/jovyan/.local/lib/python3.11/site-packages (from gdown->dgm_utils==0.1.1) (3.16.1)
# Requirement already satisfied: requests[socks] in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from gdown->dgm_utils==0.1.1) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/.local/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/.local/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/.local/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/.local/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jovyan/.local/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from matplotlib->dgm_utils==0.1.1) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from scikit-learn->dgm_utils==0.1.1) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from scikit-learn->dgm_utils==0.1.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from scikit-learn->dgm_utils==0.1.1) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (4.12.2)
# Requirement already satisfied: networkx in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (3.1.5)
# Requirement already satisfied: fsspec in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from torch->dgm_utils==0.1.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from sympy==1.13.1->torch->dgm_utils==0.1.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->dgm_utils==0.1.1) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from beautifulsoup4->gdown->dgm_utils==0.1.1) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from jinja2->torch->dgm_utils==0.1.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from requests[socks]->gdown->dgm_utils==0.1.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from requests[socks]->gdown->dgm_utils==0.1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from requests[socks]->gdown->dgm_utils==0.1.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from requests[socks]->gdown->dgm_utils==0.1.1) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/jovyan/.mlspace/envs/dgm/lib/python3.11/site-packages (from requests[socks]->gdown->dgm_utils==0.1.1) (1.7.1)
# Building wheels for collected packages: dgm_utils
#   Building wheel for dgm_utils (setup.py) ... done
#   Created wheel for dgm_utils: filename=dgm_utils-0.1.1-py3-none-any.whl size=5932 sha256=7c8b276ff8415e664f94088122da9a90721746e311a233e981789a8f73d7a6e6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_fckxqn5/wheels/b4/4f/13/f7b804b4989cb19645c4b65cb8c98c1d28ba3d7ae082eee83b
# Successfully built dgm_utils
# Installing collected packages: dgm_utils
#   Attempting uninstall: dgm_utils
#     Found existing installation: dgm_utils 0.1.1
#     Uninstalling dgm_utils-0.1.1:
#       Successfully uninstalled dgm_utils-0.1.1
# Successfully installed dgm_utils-0.1.1
# /home/jovyan/morozov_ma/dgm

# %%
from dgm_utils import plot_training_curves
from dgm_utils import show_samples, visualize_images, load_dataset

# %%
train_data_bin, test_data_bin = load_dataset("mnist", flatten=False, binarize=True)
visualize_images(train_data_bin, "Binarized MNIST samples")
train_data, test_data = load_dataset("mnist", flatten=False, binarize=False)
visualize_images(train_data, "MNIST samples")

# %%
plt.imshow(train_data[0][0], cmap="gray")
plt.show()

# %% [markdown]
# ## Pixel CNN
#
# The original article: [2016, Oord et. al.](https://arxiv.org/pdf/1601.06759.pdf)
#
# PixelCNN++: [2017, Salimans et. al.](https://arxiv.org/pdf/1701.05517.pdf)

# %% [markdown]
# ### Autoregressive models for grayscale images
#
# Let $\boldsymbol{x} \sim p(\boldsymbol{x} | \theta) \, , \, \boldsymbol{x} \in \mathbf{R}^{n \times n}$
#
# **Likelihood factorization**: $\log p(\boldsymbol{x} | \theta) = \sum\limits_{j = 1}^{n \times n} \log p\left( x_i | \boldsymbol{x}_{1:j-1} , \theta\right)$
#
# **Sampling procedure**:
#
# * Sample $\hat{x}_1 \sim p(x_1 | \theta)$
#
# * Sample $\hat{x}_2 \sim p(x_2 | \hat{x}_1 \theta)$
#
# * ...
#
# * Sample $\hat{x}_{n^2} \sim p(x_{n^2} | \hat{\boldsymbol{x}}_{1:n^2-1} , \theta)$

# %% [markdown]
# ### Ordering
#
# <center><img src="data:image/png;base64,..." width=400 /></center>

# %% [markdown]
# **Question** Will anything change in terms of mathematical formulas for an arbitrary pixel numbering order?
#
# $p(\textbf{x}) = p(x_1)p(x_2|x_1)p(x_3|x_2, x_1)...p(x_N|x_1, ..., x_{N-1})$

# %% [markdown]
# ## Take a deep breath and work on this step by step

# %% [markdown]
# ---

# %% [markdown]
# ## **Masking** to get autoregressive model

# %% [markdown]
# ### Masked convolutions
#
# * Masked convolution of **type A**:
#
# <center><img src="data:image/png;base64,..." width=600 /></center>

# %% [markdown]
# * Masked convolution of **type B** allows self-conditioning
#
# <center><img src="data:image/png;base64,..." width=1000 /></center>

# %% [markdown]
# #### Masked convolution implementation
#
# **Question** Why do we need `register_buffer` function? What is the difference between `register_buffer` and `register_parameter`?

# %%
class MaskedConv2d(nn.Conv2d):
    def __init__(
        self, 
        mask_type: str, 
        in_channels: int, 
        out_channels: int, 
        kernel_size: int = 5
    ) -> None:
        assert mask_type in ["A", "B"]
        super().__init__(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=kernel_size,
            padding=kernel_size // 2,
        )
        self.register_buffer("mask", torch.zeros_like(self.weight))
        self.create_mask(mask_type)

    def forward(
        self, 
        input: torch.Tensor
    ) -> torch.Tensor:
        # ====
        # your code
        return F.conv2d(input, self.weight * self.mask, self.bias, padding=self.padding)
        # ====

    def create_mask(
        self, 
        mask_type: str
    ) -> None:
        # ====
        # your code
        # do not forget about mask_type
        k = self.kernel_size[0]
        self.mask[:, :, : k // 2] = 1
        self.mask[:, :, k // 2, : k // 2] = 1
        if mask_type == "B":
            self.mask[:, :, k // 2, k // 2] = 1
        # ====


def test_masked_conv2d():
    layer = MaskedConv2d("A", 2, 2)
    assert np.allclose(layer.mask[:, :, 2, 2].numpy(), np.zeros((2, 2)))

    layer = MaskedConv2d("B", 2, 2)
    assert np.allclose(layer.mask[:, :, 2, 2].numpy(), np.ones((2, 2)))


test_masked_conv2d()

# %% [markdown]
# ## PixelCNN implementation details
#
# **Question 1.**: Where can we apply convolutions of **type B** to preserve autoregressive property?
#
# **Question 2.**: Input tensor shapes?
#
# **Question 3.**: Output tensor shapes?

# %% [markdown]
# * **PixelCNN** is fully convolutional NN, which applies masked convolution of **type A** to the input layer and convolutions of **type B** to the hidden layers.
#
# * It preserves spacial dimensions of a processed tensor
#
# **Question.** How to preserve spatial dimensionality of a processed tensor?

# %% [markdown]
# **Helpfull trick** [Layer Normalization](https://arxiv.org/abs/1607.06450) (applied to **channel** dimension) helps to stabilize training process.

# %% [markdown]
# **Random fact**
# https://arxiv.org/pdf/1803.08494.pdf

# %% [markdown]
# <img src="data:image/png;base64,..." width="800"/>

# %%
class LayerNorm(nn.LayerNorm):
    def __init__(self, n_filters: int) -> None:
        super().__init__(n_filters)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.permute(0, 2, 3, 1).contiguous()
        x = super().forward(x)
        return x.permute(0, 3, 1, 2).contiguous()

# %% [markdown]
# ## Generic PixelCNN model

# %%
class PixelCNNGeneric(nn.Module):

    def __init__(
        self,
        spat_shape: Tuple[int],
        hid_chans: List[int] = [64, 64, 64, 64, 64],
        out_chan: int = 2,
        kernel_size: int = 7,
        use_layer_norm: bool = True,
    ) -> None:

        super().__init__()
        self.spat_shape = spat_shape
        self.out_chan = out_chan

        # ====
        # your code
        # apply the sequence of MaskedConv2d -> LayerNorm (it is optional) -> ReLU
        # the last layer should be MaskedConv2d (not ReLU) Question: Why?
        # Note 1: the first conv layer should be of type 'A'
        # Note 2: final output_dim in MaskedConv2d must be out_chan
        model = [MaskedConv2d("A", 1, hid_chans[0], kernel_size=kernel_size)]

        for in_hid_chan, out_hid_chan in zip(hid_chans[:-1], hid_chans[1:]):
            if use_layer_norm:
                model.append(LayerNorm(in_hid_chan))
            model.append(nn.ReLU())
            model.append(
                MaskedConv2d("B", in_hid_chan, out_hid_chan, kernel_size=kernel_size)
            )

        model.extend(
            [
                nn.ReLU(),
                MaskedConv2d("B", in_channels=hid_chans[-1], out_channels=out_chan, kernel_size=1),
            ]
        )

        self.net = nn.Sequential(*model)
        # ====

    def forward(
        self, x: torch.Tensor
    ) -> torch.Tensor:
        batch_size = x.shape[0]
        out = (x.float() - 0.5) / 0.5 # Why?
        out = self.net(out)
        # =====
        # your code
        return out.view(batch_size, self.out_chan, 1, *self.spat_shape)
        # =====

# %% [markdown]
# ### PixelCNN optimization and sampling

# %% [markdown]
# **Question 1.** What is the loss function for
#
# * BinarizedMNIST problem?
#
# * Original (grayscale) MNIST problem?
#
# **Question 2.** How to sample from PixelCNN?

# %% [markdown]
# #### PixelCNN based on CrossEntropy. Implementation

# %%
import itertools

class CrossEntropyPixelCNNGeneric(PixelCNNGeneric):

    def __init__(
        self,
        spat_shape: Tuple[int],
        hid_chans: List[int] = [64, 64, 64, 64, 64],
        out_chan: int = 2,
        kernel_size: int = 7,
        use_layer_norm: bool = True,
    ) -> None:

        assert out_chan >= 2

        super().__init__(
            spat_shape, 
            hid_chans=hid_chans, 
            out_chan=out_chan, 
            kernel_size=kernel_size, 
            use_layer_norm=use_layer_norm)

        #Note! Will average the output (i.e., returns scaled log likelihood)
        # =======
        # your code
        self.loss_fn = nn.CrossEntropyLoss()
        # ======

    def sample(
        self, n: int
    ) -> np.ndarray:
        # =====
        # your code
        # Note 1: Use torch.multinomial
        # Note 2: Output values should be in [0,1]
        samples = torch.zeros(n, 1, *self.spat_shape).to(DEVICE)
        ordering = itertools.product(range(self.spat_shape[0]), range(self.spat_shape[1]))
        with torch.no_grad():
            for (r, c) in ordering:
                logits = self(samples)[..., r, c] # (bs, out_chan=K, 1)
                probs = F.softmax(logits.squeeze(-1), dim=1) # (bs, out_chan)
                samples[..., r, c] = torch.multinomial(probs, num_samples=1) / float(self.out_chan - 1) # grayscale [0,1]
        # =====
        return samples.cpu().numpy()

# %% [markdown]
# ####  PixelCNN for binarized MNIST

# %%
class BinarizedPixelCNN(CrossEntropyPixelCNNGeneric):
    def __init__(
        self,
        spat_shape: Tuple[int],
        hid_chans: List[int] = [64, 64, 64, 64, 64],
        kernel_size: int = 7,
        use_layer_norm: bool = True,
    ) -> None:

        super().__init__(
            spat_shape, 
            hid_chans=hid_chans, 
            out_chan=2, 
            kernel_size=kernel_size, 
            use_layer_norm=use_layer_norm)

    def loss(self, x: torch.Tensor) -> dict:
        # ====
        # your code
        total_loss = self.loss_fn(self(x), x.long())
        # ====
        return {"total_loss": total_loss}

# %% [markdown]
# #### PixelCNN for grayscaled MNIST

# %%
class GrayScalePixelCNN(CrossEntropyPixelCNNGeneric):
    def __init__(
        self,
        spat_shape: Tuple[int],
        hid_chans: List[int] = [64, 128, 256, 512, 256],
        kernel_size: int = 7,
        use_layer_norm: bool = True,
    ) -> None:

        super().__init__(
            spat_shape, 
            hid_chans=hid_chans, 
            out_chan=256, 
            kernel_size=kernel_size, 
            use_layer_norm=use_layer_norm)

    def loss(self, x: torch.Tensor) -> dict:
        # ====
        # your code
        # Note: x in [0, 1]
        total_loss = self.loss_fn(self(x), (x * 255.).long())
        # ====
        return {"total_loss": total_loss}

# %% [markdown]
# ### Training PixelCNN for Binarize MNIST

# %%
from dgm_utils import train_model
from torch.optim import Adam

# %%
# ====
# set your params
EPOCHS = 10  # > 5
BATCH_SIZE = 512  # any adequate value
LR = 1e-3  # < 1e-2
N_LAYERS = 5  # < 10
N_FILTERS = 128  # < 128
USE_LAYER_NORM = True
# ====

model = BinarizedPixelCNN(
    spat_shape=(28, 28),
    hid_chans = [N_FILTERS,] * N_LAYERS,
    kernel_size=5,
    use_layer_norm=USE_LAYER_NORM,
).to(DEVICE)

train_loader = Tdata.DataLoader(train_data_bin, batch_size=BATCH_SIZE, shuffle=True)
test_loader = Tdata.DataLoader(test_data_bin, batch_size=BATCH_SIZE)

optimizer = Adam(model.parameters(), lr=LR)

train_model(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    epochs=EPOCHS,
    optimizer=optimizer,
    scheduler=None,  # No scheduler for a constant learning rate
    device=DEVICE,
    loss_key="total_loss",  # Use the default loss key or specify as needed
    n_samples=100,  # Set number of samples for visualization
    visualize_samples=True  # Set to False if you don't want visualization
)
# Out:
# End of the training

# %%
samples = model.sample(25)
show_samples(samples, title="Binary MNIST samples", nrow=5)

# %% [markdown]
# #### Training PixelCNN for grayscaled MNIST

# %%
# ====
# set your params
EPOCHS = 10  # > 5
BATCH_SIZE = 128  # any adequate value
LR = 5e-3  # < 1e-2
HIDDEN_CHANNELS = [64, 128, 256, 256, 256]
USE_LAYER_NORM = True
# ====

model = GrayScalePixelCNN(
    spat_shape=(28, 28),
    hid_chans = HIDDEN_CHANNELS,
    kernel_size=5,
    use_layer_norm=USE_LAYER_NORM,
).to(DEVICE)

train_loader = Tdata.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = Tdata.DataLoader(test_data, batch_size=BATCH_SIZE)

optimizer = Adam(model.parameters(), lr=LR)

train_model(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    epochs=EPOCHS,
    optimizer=optimizer,
    scheduler=None,  # No scheduler for a constant learning rate
    device=DEVICE,
    loss_key="total_loss",  # Use the default loss key or specify as needed
    n_samples=100,  # Set number of samples for visualization
    visualize_samples=True  # Set to False if you don't want visualization
)
# Out:
# End of the training

# %%
plot_training_curves(train_losses, test_losses)

# %%
samples = model.sample(25)
show_samples(samples, title="MNIST samples", nrow=5)

# %% [markdown]
# ### PixelCNN for RGB images
#
# $p\left(x_i | \boldsymbol{x}_{1:i-1}, \theta \right) = p\left(x_{i, R} | \boldsymbol{x}_{1:i-1}, \theta \right) p\left(x_{i, G} | x_{i, R}, \boldsymbol{x}_{1:i-1}, \theta\right) p\left(x_{i, B} | x_{i, R}, x_{i, G}, \boldsymbol{x}_{1:i-1}, \theta\right)$

# %% [markdown]
# <center><img src="data:image/png;base64,..." width=500 /></center>

# %% [markdown]
# **Question 1.** Input and output tensor shapes? Loss function?
#
# **Question 2.** How to preserve `RGB` structure through the convolutions? How do convolutions look like?

# %% [markdown]
# ## Futher steps
#
# **Question.** Can PixelCNN predict something except probabilities of pixel's categorical distribution?

# %% [markdown]
# Consider more general classes of distributions ($p(x_j | \boldsymbol{x}_{1:j-1} , \theta) \sim \text{Mixture of Gaussians}$ or $\text{Mixture of Logistics}$).
#
# For example, `PixelCNN++` [link](https://arxiv.org/pdf/1701.05517.pdf) utilizes mixture of logistics.

# %% [markdown]
# ## Recap
#
# 1. **Input:** image `(batch_size, n_channels , H, W)`\
# **Output**: $\log p(\boldsymbol{x} | \theta) = \sum\limits_{j = 1}^{n \times n} \log p\left( x_i | \boldsymbol{x}_{1:j-1} , \theta\right)$  `(batch_size, K_classes, n_channels, H, W)`
# 2. **Inference**: input image $x_{i:1}$ - probability distribution $p(x_{i+1}|x_{i:1}, \theta)$ - sampling - new image $x_{i+1:1}$
# 3. **Trainig** using CrossEntropyLoss to maximize Likelihood
# 4. **Masking** to get autoregressive model
